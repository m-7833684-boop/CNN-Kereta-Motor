# %%
# !pip install torch torchvision pandas numpy matplotlib scikit-learn pillow
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (2.11.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (0.26.0+cpu)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (1.6.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch) (2025.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch) (3.0.3)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# %%
import zipfile

with zipfile.ZipFile('/dataset kereta.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/kereta')

print("Dataset kereta berjaya dibuka!")
# Out:
# Dataset kereta berjaya dibuka!

# %%
import zipfile

# Buka dataset kereta
with zipfile.ZipFile('/dataset kereta.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/kereta')

# Buka dataset motor
with zipfile.ZipFile('/dataset motor.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/motor')

print("Kedua-dua dataset berjaya dibuka!")
# Out:
# Kedua-dua dataset berjaya dibuka!

# %%
import os

print("Folder kereta:", os.listdir('/content/kereta'))
print("Folder motor:", os.listdir('/content/motor'))
# Out:
# Folder kereta: ['kereta']
# Folder motor: ['motor']

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

train_data = datasets.ImageFolder(
    '/content/kereta',
    transform=transform
)

test_data = datasets.ImageFolder(
    '/content/motor',
    transform=transform
)

print("Train:", len(train_data))
print("Test:", len(test_data))
# Out:
# Train: 1
# Test: 53

# %%
import zipfile
import os

with zipfile.ZipFile('/dataset kereta.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/dataset_kereta')

with zipfile.ZipFile('/dataset motor.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/dataset_motor')

print("Kedua-dua dataset berjaya diekstrak!")
# Out:
# Kedua-dua dataset berjaya diekstrak!

# %%
import os

print(os.listdir('/content/dataset_kereta'))
# Out:
# ['kereta']

# %%
import os

print(os.listdir('/content/dataset_kereta/kereta'))
# Out:
# ['images (51).jpg']

# %%
import os

files = os.listdir('/content/dataset_kereta/kereta')

print("Jumlah:", len(files))
print(files)
# Out:
# Jumlah: 1
# ['images (51).jpg']

# %%
import os

files = os.listdir('/content/dataset_kereta/kereta')

for i, file in enumerate(files, 1):
    print(i, file)
# Out:
# 1 images (51).jpg

# %%
import os

files = os.listdir('/content/dataset_motor/motor')

print("Jumlah gambar motor:", len(files))
# Out:
# Jumlah gambar motor: 53

# %%
import os

base = "/content/dataset_final"

folders = [
    "train/kereta",
    "train/motor",
    "test/kereta",
    "test/motor"
]

for folder in folders:
    os.makedirs(os.path.join(base, folder), exist_ok=True)

print("Folder train dan test sudah dibuat!")
# Out:
# Folder train dan test sudah dibuat!

# %%
import os
import shutil

# Lokasi gambar asal
kereta_src = "/content/dataset_kereta/kereta"
motor_src = "/content/dataset_motor/motor"

# Ambil nama fail gambar
kereta = [f for f in os.listdir(kereta_src)
          if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

motor = [f for f in os.listdir(motor_src)
         if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 40 untuk train, 10 untuk test
for f in kereta[:40]:
    shutil.copy(os.path.join(kereta_src, f),
                "/content/dataset_final/train/kereta")

for f in kereta[40:50]:
    shutil.copy(os.path.join(kereta_src, f),
                "/content/dataset_final/test/kereta")

for f in motor[:40]:
    shutil.copy(os.path.join(motor_src, f),
                "/content/dataset_final/train/motor")

for f in motor[40:50]:
    shutil.copy(os.path.join(motor_src, f),
                "/content/dataset_final/test/motor")

print("Pembahagian dataset selesai!")
print("Train kereta:", len(os.listdir("/content/dataset_final/train/kereta")))
print("Train motor:", len(os.listdir("/content/dataset_final/train/motor")))
print("Test kereta:", len(os.listdir("/content/dataset_final/test/kereta")))
print("Test motor:", len(os.listdir("/content/dataset_final/test/motor")))
# Out:
# Pembahagian dataset selesai!
# Train kereta: 1
# Train motor: 40
# Test kereta: 0
# Test motor: 10

# %%
import os

kereta_src = "/content/dataset_kereta/kereta"

files = os.listdir(kereta_src)

print("Jumlah semua fail:", len(files))

for f in files:
    print(f)
# Out:
# Jumlah semua fail: 1
# images (51).jpg

# %%
import zipfile

zip_path = "/dataset kereta.Zip.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print("Jumlah fail dalam ZIP:", len(zip_ref.namelist()))
    print("\nIsi ZIP:")
    for f in zip_ref.namelist():
        print(f)
# Out:
# Jumlah fail dalam ZIP: 51
#
# Isi ZIP:
# kereta/
# kereta/images (51).jpg
# kereta/images (26).jpg
# kereta/images (27).jpg
# kereta/images (28).jpg
# kereta/images (29).jpg
# kereta/images (30).jpg
# kereta/images (31).jpg
# kereta/images (32).jpg
# kereta/images (33).jpg
# kereta/images (34).jpg
# kereta/images (1).jpg
# kereta/images (10).jpg
# kereta/images (11).jpg
# kereta/images (12).jpg
# kereta/images (13).jpg
# kereta/images (14).jpg
# kereta/images (15).jpg
# kereta/images (16).jpg
# kereta/images (17).jpg
# kereta/images (18).jpg
# kereta/images (19).jpg
# kereta/images (2).jpg
# kereta/images (20).jpg
# kereta/images (21).jpg
# kereta/images (22).jpg
# kereta/images (23).jpg
# kereta/images (24).jpg
# kereta/images (25).jpg
# kereta/images (3).jpg
# kereta/images (35).jpg
# kereta/images (37).jpg
# kereta/images (38).jpg
# kereta/images (39).jpg
# kereta/images (4).jpg
# kereta/images (40).jpg
# kereta/images (41).jpg
# kereta/images (42).jpg
# kereta/images (43).jpg
# kereta/images (44).jpg
# kereta/images (46).jpg
# kereta/images (47).jpg
# kereta/images (48).jpg
# kereta/images (49).jpg
# kereta/images (5).jpg
# kereta/images (50).jpg
# kereta/images (6).jpg
# kereta/images (7).jpg
# kereta/images (8).jpg
# kereta/images (9).jpg
# kereta/images.jpg

# %%
import os

for f in os.listdir('/content'):
    print(f)
# Out:
# .config
# kereta_baru
# motor
# kereta
# dataset_motor
# dataset_kereta
# dataset_final
# sample_data

# %%
import os

print(os.listdir("/content/kereta_baru"))
# Out:
# ['kereta']

# %%
import os

folder = "/content/kereta_baru/kereta"

files = os.listdir(folder)

print("Jumlah fail dalam folder kereta:", len(files))
print(files)
# Out:
# Jumlah fail dalam folder kereta: 0
# []

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'kereta_baru', 'motor', 'kereta', 'dataset_motor', 'dataset_kereta', 'dataset_final', 'sample_data']

# %%
import os

print(os.listdir("/content/kereta"))
# Out:
# ['kereta']

# %%
import os

print(os.listdir("/content/kereta/kereta"))
# Out:
# ['images (51).jpg']

# %%
import os

print("Folder dataset_kereta:")
print(os.listdir("/content/dataset_kereta/kereta"))
# Out:
# Folder dataset_kereta:
# ['images (51).jpg']

# %%
import os

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file.lower().endswith(".zip"):
            print(os.path.join(root, file))

# %%
import zipfile
import os

zip_path = "/dataset kereta.zip"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    print("Jumlah fail dalam ZIP:", len(zip_ref.namelist()))
    print(zip_ref.namelist()[:10])
# Out:
# Jumlah fail dalam ZIP: 51
# ['kereta/', 'kereta/images (51).jpg', 'kereta/images (26).jpg', 'kereta/images (27).jpg', 'kereta/images (28).jpg', 'kereta/images (29).jpg', 'kereta/images (30).jpg', 'kereta/images (31).jpg', 'kereta/images (32).jpg', 'kereta/images (33).jpg']

# %%
import zipfile
import os

zip_path = "/dataset kereta.zip"
extract_path = "/content/kereta_lengkap"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Berjaya extract!")
print("Jumlah gambar:", len(os.listdir("/content/kereta_lengkap/kereta")))
# Out:
# Berjaya extract!
# Jumlah gambar: 50

# %%
import os

print(os.listdir("/content/kereta_lengkap/kereta"))
print("Jumlah gambar:", len(os.listdir("/content/kereta_lengkap/kereta")))
# Out:
# ['images (20).jpg', 'images (22).jpg', 'images (7).jpg', 'images (50).jpg', 'images (28).jpg', 'images (32).jpg', 'images (40).jpg', 'images (17).jpg', 'images (39).jpg', 'images (26).jpg', 'images (29).jpg', 'images (35).jpg', 'images (25).jpg', 'images (10).jpg', 'images (46).jpg', 'images (15).jpg', 'images (1).jpg', 'images (14).jpg', 'images.jpg', 'images (21).jpg', 'images (12).jpg', 'images (43).jpg', 'images (51).jpg', 'images (27).jpg', 'images (19).jpg', 'images (9).jpg', 'images (24).jpg', 'images (42).jpg', 'images (18).jpg', 'images (4).jpg', 'images (13).jpg', 'images (23).jpg', 'images (31).jpg', 'images (49).jpg', 'images (30).jpg', 'images (16).jpg', 'images (11).jpg', 'images (33).jpg', 'images (5).jpg', 'images (37).jpg', 'images (47).jpg', 'images (2).jpg', 'images (44).jpg', 'images (8).jpg', 'images (34).jpg', 'images (3).jpg', 'images (38).jpg', 'images (41).jpg', 'images (6).jpg', 'images (48).jpg']
# Jumlah gambar: 50

# %%
import os
import shutil

kereta_src = "/content/kereta_lengkap/kereta"

train_kereta = "/content/dataset_final/train/kereta"
test_kereta = "/content/dataset_final/test/kereta"

# Pastikan folder wujud
os.makedirs(train_kereta, exist_ok=True)
os.makedirs(test_kereta, exist_ok=True)

# Ambil semua gambar
kereta = os.listdir(kereta_src)

# 40 gambar untuk training
for f in kereta[:40]:
    shutil.copy(
        os.path.join(kereta_src, f),
        train_kereta
    )

# 10 gambar untuk testing
for f in kereta[40:50]:
    shutil.copy(
        os.path.join(kereta_src, f),
        test_kereta
    )

print("Train kereta:", len(os.listdir(train_kereta)))
print("Test kereta:", len(os.listdir(test_kereta)))
# Out:
# Train kereta: 40
# Test kereta: 10

# %%
import os

motor_src = "/content/motor/motor"

print("Jumlah gambar motor:", len(os.listdir(motor_src)))
# Out:
# Jumlah gambar motor: 53

# %%
import os
import shutil

motor_src = "/content/motor/motor"

train_motor = "/content/dataset_final/train/motor"
test_motor = "/content/dataset_final/test/motor"

os.makedirs(train_motor, exist_ok=True)
os.makedirs(test_motor, exist_ok=True)

motor = os.listdir(motor_src)

# 40 gambar untuk training
for f in motor[:40]:
    shutil.copy(
        os.path.join(motor_src, f),
        train_motor
    )

# 10 gambar untuk testing
for f in motor[40:50]:
    shutil.copy(
        os.path.join(motor_src, f),
        test_motor
    )

print("Train motor:", len(os.listdir(train_motor)))
print("Test motor:", len(os.listdir(test_motor)))
# Out:
# Train motor: 40
# Test motor: 10

# %%
import os

print("Train kereta:", len(os.listdir("/content/dataset_final/train/kereta")))
print("Train motor:", len(os.listdir("/content/dataset_final/train/motor")))
print("Test kereta:", len(os.listdir("/content/dataset_final/test/kereta")))
print("Test motor:", len(os.listdir("/content/dataset_final/test/motor")))
# Out:
# Train kereta: 40
# Train motor: 40
# Test kereta: 10
# Test motor: 10

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

train_dataset = datasets.ImageFolder(
    "/content/dataset_final/train",
    transform=train_transform
)

test_dataset = datasets.ImageFolder(
    "/content/dataset_final/test",
    transform=test_transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=8,
    shuffle=False
)

print("Kelas:", train_dataset.classes)
print("Jumlah data train:", len(train_dataset))
print("Jumlah data test:", len(test_dataset))
# Out:
# Kelas: ['kereta', 'motor']
# Jumlah data train: 80
# Jumlah data test: 20

# %%
import torch
import torch.nn as nn

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)

        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(64 * 16 * 16, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))

        x = x.view(x.size(0), -1)

        x = torch.relu(self.fc1(x))
        x = self.fc2(x)

        return x

model = CNN()

print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=16384, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=0.001
)

print("Loss function:", criterion)
print("Optimizer:", optimizer)
# Out:
# Loss function: CrossEntropyLoss()
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
num_epochs = 10

train_losses = []
train_accuracies = []

for epoch in range(num_epochs):
    model.train()

    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    epoch_accuracy = 100 * correct / total

    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)

    print(
        f"Epoch [{epoch+1}/{num_epochs}] "
        f"Loss: {epoch_loss:.4f} "
        f"Accuracy: {epoch_accuracy:.2f}%"
    )
# Out:
# Epoch [1/10] Loss: 0.7395 Accuracy: 55.00%
# Epoch [2/10] Loss: 0.6936 Accuracy: 53.75%
# Epoch [3/10] Loss: 0.6542 Accuracy: 63.75%
# Epoch [4/10] Loss: 0.5430 Accuracy: 75.00%
# Epoch [5/10] Loss: 0.4410 Accuracy: 80.00%
# Epoch [6/10] Loss: 0.4640 Accuracy: 81.25%
# Epoch [7/10] Loss: 0.3200 Accuracy: 88.75%
# Epoch [8/10] Loss: 0.2679 Accuracy: 86.25%
# Epoch [9/10] Loss: 0.2633 Accuracy: 87.50%
# Epoch [10/10] Loss: 0.1649 Accuracy: 95.00%

# %%
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total

print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 90.00%

# %%
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total

print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 90.00%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(train_losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import torch

class_names = train_dataset.classes

model.eval()

images, labels = next(iter(test_loader))

with torch.no_grad():
    outputs = model(images)
    _, predictions = torch.max(outputs, 1)

plt.figure(figsize=(12, 8))

for i in range(min(8, len(images))):
    image = images[i].permute(1, 2, 0)

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)
    plt.title(
        f"Actual: {class_names[labels[i]]}\n"
        f"Pred: {class_names[predictions[i]]}"
    )
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn) (3.1.2)

# %%
from sklearn.metrics import classification_report

model.eval()

all_labels = []
all_predictions = []

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)

        all_labels.extend(labels.numpy())
        all_predictions.extend(predictions.numpy())

print(classification_report(
    all_labels,
    all_predictions,
    target_names=class_names
))
# Out:
#               precision    recall  f1-score   support
#
#       kereta       0.90      0.90      0.90        10
#        motor       0.90      0.90      0.90        10
#
#     accuracy                           0.90        20
#    macro avg       0.90      0.90      0.90        20
# weighted avg       0.90      0.90      0.90        20

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(all_labels, all_predictions)

plt.figure(figsize=(6, 5))
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.xticks(
    range(len(class_names)),
    class_names
)

plt.yticks(
    range(len(class_names)),
    class_names
)

for i in range(len(class_names)):
    for j in range(len(class_names)):
        plt.text(j, i, cm[i, j],
                 ha="center",
                 va="center")

plt.colorbar()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

def create_model():
    return CNN()

# %%
experiments = [
    {"lr": 0.001, "batch_size": 8},
    {"lr": 0.0005, "batch_size": 8},
    {"lr": 0.001, "batch_size": 16}
]

results = []

for exp in experiments:

    print("\n==============================")
    print("Learning Rate:", exp["lr"])
    print("Batch Size:", exp["batch_size"])
    print("==============================")

    train_loader_exp = DataLoader(
        train_dataset,
        batch_size=exp["batch_size"],
        shuffle=True
    )

    test_loader_exp = DataLoader(
        test_dataset,
        batch_size=exp["batch_size"],
        shuffle=False
    )

    model_exp = create_model()

    criterion_exp = nn.CrossEntropyLoss()

    optimizer_exp = optim.Adam(
        model_exp.parameters(),
        lr=exp["lr"]
    )

    # Training
    for epoch in range(10):

        model_exp.train()

        for images, labels in train_loader_exp:

            optimizer_exp.zero_grad()

            outputs = model_exp(images)

            loss = criterion_exp(
                outputs,
                labels
            )

            loss.backward()

            optimizer_exp.step()

    # Testing
    model_exp.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in test_loader_exp:

            outputs = model_exp(images)

            _, predicted = torch.max(
                outputs,
                1
            )

            total += labels.size(0)

            correct += (
                predicted == labels
            ).sum().item()

    accuracy = 100 * correct / total

    results.append({
        "Learning Rate": exp["lr"],
        "Batch Size": exp["batch_size"],
        "Test Accuracy (%)": accuracy
    })

    print(
        f"Test Accuracy: {accuracy:.2f}%"
    )
# Out:
# ==============================
# Learning Rate: 0.001
# Batch Size: 8
# ==============================
# Test Accuracy: 90.00%
#
# ==============================
# Learning Rate: 0.0005
# Batch Size: 8
# ==============================
# Test Accuracy: 80.00%
#
# ==============================
# Learning Rate: 0.001
# Batch Size: 16
# ==============================
# Test Accuracy: 80.00%

# %%
import pandas as pd

results_df = pd.DataFrame(results)

print(results_df)
# Out:
#    Learning Rate  Batch Size  Test Accuracy (%)
# 0         0.0010           8               90.0
# 1         0.0005           8               80.0
# 2         0.0010          16               80.0

# %%
plt.figure(figsize=(8,5))

labels = [
    f"LR={row['Learning Rate']}, BS={row['Batch Size']}"
    for _, row in results_df.iterrows()
]

plt.bar(
    labels,
    results_df["Test Accuracy (%)"]
)

plt.xlabel("Hyperparameter")
plt.ylabel("Test Accuracy (%)")
plt.title("Perbandingan Hyperparameter")
plt.xticks(rotation=20)
plt.show()

# %%
torch.save(
    model.state_dict(),
    "/content/cnn_kereta_motor.pth"
)

print("Model berjaya disimpan.")
# Out:
# Model berjaya disimpan.

# %%
import json

with open("/content/classes.json", "w") as f:
    json.dump(class_names, f)

print("Nama kelas:", class_names)
# Out:
# Nama kelas: ['kereta', 'motor']

# %%
import numpy as np
import pandas as pd

data = np.array(train_accuracies)

accuracy_df = pd.DataFrame({
    "Epoch": np.arange(1, len(data) + 1),
    "Training Accuracy (%)": data
})

print(accuracy_df)
# Out:
#    Epoch  Training Accuracy (%)
# 0      1                  55.00
# 1      2                  53.75
# 2      3                  63.75
# 3      4                  75.00
# 4      5                  80.00
# 5      6                  81.25
# 6      7                  88.75
# 7      8                  86.25
# 8      9                  87.50
# 9     10                  95.00

# %%
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total

print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 90.00%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(train_losses, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(train_accuracies, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy")
plt.grid()
plt.show()

# %%
from sklearn.metrics import classification_report

model.eval()

all_labels = []
all_predictions = []

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)

        all_labels.extend(labels.numpy())
        all_predictions.extend(predictions.numpy())

print(classification_report(
    all_labels,
    all_predictions,
    target_names=train_dataset.classes
))
# Out:
#               precision    recall  f1-score   support
#
#       kereta       0.90      0.90      0.90        10
#        motor       0.90      0.90      0.90        10
#
#     accuracy                           0.90        20
#    macro avg       0.90      0.90      0.90        20
# weighted avg       0.90      0.90      0.90        20

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(all_labels, all_predictions)

plt.figure(figsize=(6,5))
plt.imshow(cm)

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.xticks(
    range(len(train_dataset.classes)),
    train_dataset.classes
)

plt.yticks(
    range(len(train_dataset.classes)),
    train_dataset.classes
)

for i in range(len(train_dataset.classes)):
    for j in range(len(train_dataset.classes)):
        plt.text(
            j, i, cm[i, j],
            ha="center",
            va="center"
        )

plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

model.eval()

images, labels = next(iter(test_loader))

with torch.no_grad():
    outputs = model(images)
    _, predictions = torch.max(outputs, 1)

plt.figure(figsize=(12,8))

for i in range(min(8, len(images))):

    image = images[i].permute(1, 2, 0)

    plt.subplot(2,4,i+1)

    plt.imshow(image)

    plt.title(
        f"Actual: {train_dataset.classes[labels[i]]}\n"
        f"Pred: {train_dataset.classes[predictions[i]]}"
    )

    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

experiments = [
    {"lr": 0.001, "batch_size": 8},
    {"lr": 0.0005, "batch_size": 8},
    {"lr": 0.001, "batch_size": 16}
]

results = []

for exp in experiments:

    print("\n==============================")
    print("Learning Rate:", exp["lr"])
    print("Batch Size:", exp["batch_size"])
    print("==============================")

    train_loader_exp = DataLoader(
        train_dataset,
        batch_size=exp["batch_size"],
        shuffle=True
    )

    test_loader_exp = DataLoader(
        test_dataset,
        batch_size=exp["batch_size"],
        shuffle=False
    )

    model_exp = CNN()

    criterion_exp = nn.CrossEntropyLoss()

    optimizer_exp = optim.Adam(
        model_exp.parameters(),
        lr=exp["lr"]
    )

    for epoch in range(10):

        model_exp.train()

        for images, labels in train_loader_exp:

            optimizer_exp.zero_grad()

            outputs = model_exp(images)

            loss = criterion_exp(
                outputs,
                labels
            )

            loss.backward()

            optimizer_exp.step()

    model_exp.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in test_loader_exp:

            outputs = model_exp(images)

            _, predicted = torch.max(
                outputs, 1
            )

            total += labels.size(0)

            correct += (
                predicted == labels
            ).sum().item()

    accuracy = 100 * correct / total

    results.append({
        "Learning Rate": exp["lr"],
        "Batch Size": exp["batch_size"],
        "Test Accuracy (%)": accuracy
    })

    print(
        f"Test Accuracy: {accuracy:.2f}%"
    )
# Out:
# ==============================
# Learning Rate: 0.001
# Batch Size: 8
# ==============================
# Test Accuracy: 90.00%
#
# ==============================
# Learning Rate: 0.0005
# Batch Size: 8
# ==============================
# Test Accuracy: 90.00%
#
# ==============================
# Learning Rate: 0.001
# Batch Size: 16
# ==============================
# Test Accuracy: 85.00%

# %%
import pandas as pd

results_df = pd.DataFrame(results)

results_df
# Out:
#    Learning Rate  Batch Size  Test Accuracy (%)
# 0         0.0010           8               90.0
# 1         0.0005           8               90.0
# 2         0.0010          16               85.0

# %%
import matplotlib.pyplot as plt

labels = [
    f"LR={row['Learning Rate']}, BS={row['Batch Size']}"
    for _, row in results_df.iterrows()
]

plt.figure(figsize=(8,5))

plt.bar(
    labels,
    results_df["Test Accuracy (%)"]
)

plt.xlabel("Hyperparameter")
plt.ylabel("Test Accuracy (%)")
plt.title("Perbandingan Hyperparameter")
plt.xticks(rotation=20)

plt.show()

# %%
torch.save(
    model.state_dict(),
    "/content/cnn_kereta_motor.pth"
)

print("Model berjaya disimpan.")
# Out:
# Model berjaya disimpan.

# %%
import json

class_names = train_dataset.classes

with open("/content/classes.json", "w") as f:
    json.dump(class_names, f)

print("Kelas:", class_names)
# Out:
# Kelas: ['kereta', 'motor']

# %%
import numpy as np
import pandas as pd

accuracy_array = np.array(train_accuracies)

accuracy_df = pd.DataFrame({
    "Epoch": np.arange(1, len(accuracy_array) + 1),
    "Training Accuracy (%)": accuracy_array
})

accuracy_df
# Out:
#    Epoch  Training Accuracy (%)
# 0      1                  55.00
# 1      2                  53.75
# 2      3                  63.75
# 3      4                  75.00
# 4      5                  80.00
# 5      6                  81.25
# 6      7                  88.75
# 7      8                  86.25
# 8      9                  87.50
# 9     10                  95.00

# %%
from sklearn.metrics import classification_report

model.eval()

all_labels = []
all_predictions = []

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)

        all_labels.extend(labels.numpy())
        all_predictions.extend(predictions.numpy())

print(classification_report(
    all_labels,
    all_predictions,
    target_names=train_dataset.classes
))
# Out:
#               precision    recall  f1-score   support
#
#       kereta       0.90      0.90      0.90        10
#        motor       0.90      0.90      0.90        10
#
#     accuracy                           0.90        20
#    macro avg       0.90      0.90      0.90        20
# weighted avg       0.90      0.90      0.90        20

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(all_labels, all_predictions)

plt.figure(figsize=(6,5))
plt.imshow(cm)

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.xticks(range(len(train_dataset.classes)), train_dataset.classes)
plt.yticks(range(len(train_dataset.classes)), train_dataset.classes)

for i in range(len(train_dataset.classes)):
    for j in range(len(train_dataset.classes)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.colorbar()
plt.show()

# %%
model.eval()

images, labels = next(iter(test_loader))

with torch.no_grad():
    outputs = model(images)
    _, predictions = torch.max(outputs, 1)

plt.figure(figsize=(12, 8))

for i in range(min(8, len(images))):
    image = images[i].permute(1, 2, 0)

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    plt.title(
        f"Actual: {train_dataset.classes[labels[i]]}\n"
        f"Pred: {train_dataset.classes[predictions[i]]}"
    )

    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Hyperparameter Tuning

from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import pandas as pd

experiments = [
    {"lr": 0.001, "batch_size": 8},
    {"lr": 0.0005, "batch_size": 8},
    {"lr": 0.001, "batch_size": 16}
]

results = []

for exp in experiments:

    print("====================================")
    print("Learning Rate:", exp["lr"])
    print("Batch Size:", exp["batch_size"])

    # DataLoader
    train_loader_exp = DataLoader(
        train_dataset,
        batch_size=exp["batch_size"],
        shuffle=True
    )

    test_loader_exp = DataLoader(
        test_dataset,
        batch_size=exp["batch_size"],
        shuffle=False
    )

    # Model baru
    model_exp = CNN()

    # Loss
    criterion_exp = nn.CrossEntropyLoss()

    # Optimizer
    optimizer_exp = optim.Adam(
        model_exp.parameters(),
        lr=exp["lr"]
    )

    # Training
    for epoch in range(10):

        model_exp.train()

        for images, labels in train_loader_exp:

            optimizer_exp.zero_grad()

            outputs = model_exp(images)

            loss = criterion_exp(outputs, labels)

            loss.backward()

            optimizer_exp.step()

    # Testing
    model_exp.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in test_loader_exp:

            outputs = model_exp(images)

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total

    print(f"Test Accuracy: {accuracy:.2f}%")

    results.append({
        "Learning Rate": exp["lr"],
        "Batch Size": exp["batch_size"],
        "Test Accuracy (%)": accuracy
    })


# Paparkan keputusan dalam jadual
results_df = pd.DataFrame(results)

print("\nKEPUTUSAN HYPERPARAMETER TUNING")
print(results_df)
# Out:
# ====================================
# Learning Rate: 0.001
# Batch Size: 8
# Test Accuracy: 95.00%
# ====================================
# Learning Rate: 0.0005
# Batch Size: 8
# Test Accuracy: 90.00%
# ====================================
# Learning Rate: 0.001
# Batch Size: 16
# Test Accuracy: 85.00%
#
# KEPUTUSAN HYPERPARAMETER TUNING
#    Learning Rate  Batch Size  Test Accuracy (%)
# 0         0.0010           8               95.0
# 1         0.0005           8               90.0
# 2         0.0010          16               85.0

# %%
import matplotlib.pyplot as plt

labels = [
    f"LR={row['Learning Rate']}\nBS={row['Batch Size']}"
    for _, row in results_df.iterrows()
]

accuracies = results_df["Test Accuracy (%)"]

plt.figure(figsize=(8,5))

plt.bar(labels, accuracies)

plt.xlabel("Hyperparameter")
plt.ylabel("Test Accuracy (%)")
plt.title("Perbandingan Hyperparameter Tuning")

for i, value in enumerate(accuracies):
    plt.text(i, value + 0.5, f"{value:.2f}%", ha="center")

plt.ylim(0, 100)
plt.show()

# %%
# Simpan model CNN
torch.save(model.state_dict(), "/content/cnn_kereta_motor.pth")

print("Model berjaya disimpan!")
# Out:
# Model berjaya disimpan!

# %%
import json

class_names = train_dataset.classes

with open("/content/classes.json", "w") as f:
    json.dump(class_names, f)

print("Class names:", class_names)
# Out:
# Class names: ['kereta', 'motor']

# %%
import json

class_names = train_dataset.classes

with open("/content/classes.json", "w") as f:
    json.dump(class_names, f)

print(class_names)
# Out:
# ['kereta', 'motor']
